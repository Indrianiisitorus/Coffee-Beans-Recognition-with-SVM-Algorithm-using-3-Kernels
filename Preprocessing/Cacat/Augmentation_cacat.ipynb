# %% [markdown]
# # Importing required libraries

# %%
import cv2
import glob
import matplotlib.pyplot as plt
import os,glob
import os
from os import listdir,makedirs
from os.path import isfile,join
import skimage
from skimage import data
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image

# %% [markdown]
# # Load the image

# %%
# load image Cacat1.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat1.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat1_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat1_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat1_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat1_90.png')

# %%
# load image Cacat2.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat2.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat2_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat2_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat2_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat2_90.png')

# %%
# load image Cacat3.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat3.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat3_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat3_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat3_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat3_90.png')

# %%
# load image Cacat4.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat4.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat4_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat4_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat4_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat4_90.png')

# %%
# load image Cacat5.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat5.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat5_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat5_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat5_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat5_90.png')

# %%
# load image Cacat6.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat6.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat6_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat6_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat6_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat6_90.png')

# %%
# load image Cacat7.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat7.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat7_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat7_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat7_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat7_90.png')

# %%
# load image Cacat8.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat8.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat8_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat8_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat8_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat8_90.png')

# %%
# load image Cacat9.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat9.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat9_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat9_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat9_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat9_90.png')

# %%
# load image Cacat10.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat10.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat10_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat10_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat10_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat10_90.png')

# %%
# load image Cacat11.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat11.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat11_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat11_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat11_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat11_90.png')

# %%
# load image Cacat12.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat12.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat12_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat12_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat12_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat12_90.png')

# %%
# load image Cacat13.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat13.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat13_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat13_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat13_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat13_90.png')

# %%
# load image Cacat14.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat14.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat14_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat14_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat14_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat14_90.png')

# %%
# load image Cacat15.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat15.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat15_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat15_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat15_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat15_90.png')

# %%
# load image Cacat16.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat16.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat16_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat16_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat16_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat16_90.png')

# %%
# load image Cacat17.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat17.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat17_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat17_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat17_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat17_90.png')

# %%
# load image Cacat18.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat18.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat18_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat18_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat18_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat18_90.png')

# %%
# load image Cacat19.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat19.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat19_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat19_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat19_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat19_90.png')

# %%
# load image Cacat20.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat20.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat20_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat20_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat20_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat20_90.png')

# %%
# load image Cacat21.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat21.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat21_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat21_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat21_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat21_90.png')

# %%
# load image Cacat22.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat22.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat22_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat22_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat22_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat22_90.png')

# %%
# load image Cacat23.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat23.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat23_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat23_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat23_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat23_90.png')

# %%
# load image Cacat24.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat24.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat24_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat24_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat24_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat24_90.png')

# %%
# load image Cacat25.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat25.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat25_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat25_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat25_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat25_90.png')

# %%
# load image Cacat26.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat26.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat26_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat26_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat26_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat26_90.png')

# %%
# load image Cacat27.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat27.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat27_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat27_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat27_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat27_90.png')

# %%
# load image Cacat28.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat28.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat28_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat28_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat28_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat28_90.png')

# %%
# load image Cacat29.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat29.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat29_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat29_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat29_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat29_90.png')

# %%
# load image Cacat30.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat30.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat30_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat30_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat30_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat30_90.png')

# %%
# load image Cacat31.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat31.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat31_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat31_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat31_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat31_90.png')

# %%
# load image Cacat32.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat32.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat32_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat32_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat32_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat32_90.png')

# %%
# load image Cacat33.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat33.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat33_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat33_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat33_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat33_90.png')

# %%
# load image Cacat34.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat34.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat34_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat34_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat34_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat34_90.png')

# %%
# load image Cacat35.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat35.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat35_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat35_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat35_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat35_90.png')

# %%
# load image Cacat36.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat36.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat36_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat36_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat36_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat36_90.png')

# %%
# load image Cacat37.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat37.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat37_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat37_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat37_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat37_90.png')

# %%
# load image Cacat38.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat38.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat38_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat38_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat38_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat38_90.png')

# %%
# load image Cacat39.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat39.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat39_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat39_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat39_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat39_90.png')

# %%
# load image Cacat40.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat40.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat40_30.png')
a
# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat40_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat40_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat40_90.png')

# %%
# load image Cacat41.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat41.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat41_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat41_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat41_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat41_90.png')

# %%
# load image Cacat42.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat42.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat42_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat42_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat42_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat42_90.png')

# %%
# load image Cacat43.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat43.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat43_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat43_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat43_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat43_90.png')

# %%
# load image Cacat44.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat44.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat44_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat44_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat44_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat44_90.png')

# %%
# load image Cacat45.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat45.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat45_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat45_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat45_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat45_90.png')

# %%
# load image Cacat46.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat46.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat46_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat46_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat46_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat46_90.png')

# %%
# load image Cacat47.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat47.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat47_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat47_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat47_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat47_90.png')

# %%
# load image Cacat48.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat48.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat48_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat48_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat48_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat48_90.png')

# %%
# load image Cacat49.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat49.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat49_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat49_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat49_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat49_90.png')

# %%
# load image Cacat50.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat50.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat50_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat50_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat50_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat50_90.png')

# %%
# load image Cacat51.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat51.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat51_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat51_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat51_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat51_90.png')

# %%
# load image Cacat52.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat52.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat52_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat52_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat52_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat52_90.png')

# %%
# load image Cacat53.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat53.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat53_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat53_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat53_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat53_90.png')

# %%
# load image Cacat54.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat54.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat54_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat54_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat54_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat54_90.png')

# %%
# load image Cacat55.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat55.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat55_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat55_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat55_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat55_90.png')

# %%
# load image Cacat56.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat56.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat56_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat56_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat56_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat56_90.png')

# %%
# load image Cacat57.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat57.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat57_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat57_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat57_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat57_90.png')

# %%
# load image Cacat58.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat58.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat58_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat58_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat58_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat58_90.png')

# %%
# load image Cacat59.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat59.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat59_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat59_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat59_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat59_90.png')

# %%
# load image Cacat60.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat60.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat60_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat60_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat60_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat60_90.png')

# %%
# load image Cacat61.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat61.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat61_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat61_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat61_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat61_90.png')

# %%
# load image Cacat62.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat62.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat62_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat62_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat62_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat62_90.png')

# %%
# load image Cacat63.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat63.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat63_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat63_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat63_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat63_90.png')

# %%
# load image Cacat64.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat64.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat64_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat64_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat64_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat64_90.png')

# %%
# load image Cacat65.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat65.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat65_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat65_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat65_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat65_90.png')

# %%
# load image Cacat66.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat66.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat66_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat66_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat66_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat66_90.png')

# %%
# load image Cacat67.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat67.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat67_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat67_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat67_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat67_90.png')

# %%
# load image Cacat68.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat68.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat68_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat68_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat68_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat68_90.png')

# %%
# load image Cacat69.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat69.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat69_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat69_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat69_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat69_90.png')

# %%
# load image Cacat70.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat70.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat70_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat70_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat70_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat70_90.png')

# %%
# load image Cacat71.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat71.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat71_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat71_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat71_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat71_90.png')

# %%
# load image Cacat72.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat72.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat72_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat72_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat72_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat72_90.png')

# %%
# load image Cacat73.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat73.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat73_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat73_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat73_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat73_90.png')

# %%
# load image Cacat74.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat74.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat74_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat74_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat74_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat74_90.png')

# %%
# load image Cacat75.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat75.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat75_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat75_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat75_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat75_90.png')

# %%
# load image Cacat76.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat76.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat76_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat76_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat76_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat76_90.png')

# %%
# load image Cacat77.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat77.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat77_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat77_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat77_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat77_90.png')

# %%
# load image Cacat78.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat78.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat78_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat78_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat78_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat78_90.png')

# %%
# load image Cacat79.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat79.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat79_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat79_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat79_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat79_90.png')

# %%
# load image Cacat80.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat80.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat80_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat80_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat80_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat80_90.png')

# %%
# load image Cacat81.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat81.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat81_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat81_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat81_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat81_90.png')

# %%
# load image Cacat82.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat82.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat82_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat82_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat82_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat82_90.png')

# %%
# load image Cacat83.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat83.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat83_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat83_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat83_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat83_90.png')

# %%
# load image Cacat84.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat84.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat84_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat84_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat84_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat84_90.png')

# %%
# load image Cacat85.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat85.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat85_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat85_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat85_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat85_90.png')

# %%
# load image Cacat86.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat86.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat86_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat86_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat86_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat86_90.png')

# %%
# load image Cacat87.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat87.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat87_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat87_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat87_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat87_90.png')

# %%
# load image Cacat88.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat88.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat88_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat88_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat88_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat88_90.png')

# %%
# load image Cacat89.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat89.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat89_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat89_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat89_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat89_90.png')

# %%
# load image Cacat90.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat90.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat90_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat90_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat90_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat90_90.png')

# %%
# load image Cacat91.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat91.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat91_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat91_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat91_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat91_90.png')

# %%
# load image Cacat92.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat92.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat92_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat92_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat92_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat92_90.png')

# %%
# load image Cacat93.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat93.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat93_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat93_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat93_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat93_90.png')

# %%
# load image Cacat94.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat94.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat94_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat94_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat94_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat94_90.png')

# %%
# load image Cacat95.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat95.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat95_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat95_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat95_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat95_90.png')

# %%
# load image Cacat96.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat96.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat96_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat96_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat96_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat96_90.png')

# %%
# load image Cacat97.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat97.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat97_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat97_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat97_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat97_90.png')

# %%
# load image Cacat98.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat98.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat98_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat98_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat98_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat98_90.png')

# %%
# load image Cacat99.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat99.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat99_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat99_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat99_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat99_90.png')

# %%
# load image Cacat100.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Cacat/Cacat100.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat100_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat100_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat100_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Cacat/Augmentation/Cacat100_90.png')

# %%
import cv2
import glob
import matplotlib.pyplot as plt
import os,glob
import os
from os import listdir,makedirs
from os.path import isfile,join
import skimage
from skimage import data
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image

# %%
# load image Cacat1.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat1.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat1_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat1_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat1_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat1_90.png')

# %%
# load image Cacat2.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat2.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat2_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat2_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat2_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat2_90.png')

# %%
# load image Cacat3.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat3.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat3_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat3_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat3_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat3_90.png')

# %%
# load image Cacat4.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat4.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat4_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat4_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat4_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat4_90.png')

# %%
# load image Cacat5.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat5.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat5_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat5_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat5_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat5_90.png')

# %%
# load image Cacat6.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat6.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat6_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat6_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat6_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat6_90.png')

# %%
# load image Cacat7.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat7.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat7_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat7_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat7_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat7_90.png')

# %%
# load image Cacat8.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat8.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat8_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat8_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat8_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat8_90.png')

# %%
# load image Cacat9.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat9.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat9_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat9_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat9_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat9_90.png')

# %%
# load image Cacat10.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat10.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat10_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat10_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat10_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat10_90.png')

# %%
# load image Cacat11.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat11.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat11_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat11_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat11_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat11_90.png')

# %%
# load image Cacat12.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat12.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat12_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat12_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat12_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat12_90.png')

# %%
# load image Cacat13.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat13.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat13_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat13_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat13_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat13_90.png')

# %%
# load image Cacat14.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat14.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat14_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat14_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat14_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat14_90.png')

# %%
# load image Cacat15.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat15.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat15_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat15_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat15_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat15_90.png')

# %%
# load image Cacat16.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat16.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat16_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat16_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat16_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat16_90.png')

# %%
# load image Cacat17.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat17.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat17_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat17_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat17_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat17_90.png')

# %%
# load image Cacat18.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat18.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat18_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat18_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat18_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat18_90.png')

# %%
# load image Cacat19.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat19.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat19_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat19_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat19_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat19_90.png')

# %%
# load image Cacat20.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat20.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat20_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat20_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat20_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat20_90.png')

# %%
# load image Cacat21.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat21.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat21_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat21_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat21_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat21_90.png')

# %%
# load image Cacat22.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat22.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat22_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat22_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat22_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat22_90.png')

# %%
# load image Cacat23.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat23.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat23_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat23_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat23_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat23_90.png')

# %%
# load image Cacat24.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat24.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat24_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat24_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat24_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat24_90.png')

# %%
# load image Cacat25.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat25.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat25_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat25_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat25_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat25_90.png')

# %%
# load image Cacat26.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat26.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat26_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat26_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat26_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat26_90.png')

# %%
# load image Cacat27.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat27.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat27_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat27_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat27_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat27_90.png')

# %%
# load image Cacat28.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat28.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat28_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat28_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat28_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat28_90.png')

# %%
# load image Cacat29.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat29.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat29_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat29_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat29_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat29_90.png')

# %%
# load image Cacat30.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat30.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat30_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat30_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat30_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat30_90.png')

# %%
# load image Cacat31.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat31.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat31_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat31_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat31_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat31_90.png')

# %%
# load image Cacat32.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat32.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat32_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat32_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat32_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat32_90.png')

# %%
# load image Cacat33.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat33.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat33_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat33_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat33_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat33_90.png')

# %%
# load image Cacat34.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat34.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat34_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat34_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat34_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat34_90.png')

# %%
# load image Cacat35.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat35.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat35_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat35_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat35_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat35_90.png')

# %%
# load image Cacat36.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat36.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat36_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat36_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat36_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat36_90.png')

# %%
# load image Cacat37.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat37.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat37_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat37_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat37_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat37_90.png')

# %%
# load image Cacat38.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat38.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat38_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat38_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat38_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat38_90.png')

# %%
# load image Cacat39.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat39.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat39_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat39_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat39_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat39_90.png')

# %%
# load image Cacat40.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat40.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat40_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat40_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat40_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat40_90.png')

# %%
# load image Cacat41.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat41.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat41_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat41_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat41_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat41_90.png')

# %%
# load image Cacat42.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat42.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat42_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat42_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat42_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat42_90.png')

# %%
# load image Cacat43.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat43.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat43_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat43_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat43_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat43_90.png')

# %%
# load image Cacat44.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat44.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat44_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat44_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat44_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat44_90.png')

# %%
# load image Cacat45.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat45.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat45_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat45_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat45_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat45_90.png')

# %%
# load image Cacat46.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat46.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat46_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat46_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat46_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat46_90.png')

# %%
# load image Cacat47.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat47.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat47_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat47_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat47_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat47_90.png')

# %%
# load image Cacat48.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat48.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat48_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat48_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat48_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat48_90.png')

# %%
# load image Cacat49.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat49.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat49_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat49_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat49_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat49_90.png')

# %%
# load image Cacat50.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat50.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat50_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat50_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat50_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat50_90.png')

# %%
# load image Cacat51.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat51.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat51_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat51_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat51_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat51_90.png')

# %%
# load image Cacat52.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat52.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat52_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat52_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat52_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat52_90.png')

# %%
# load image Cacat53.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat53.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat53_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat53_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat53_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat53_90.png')

# %%
# load image Cacat54.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat54.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat54_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat54_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat54_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat54_90.png')

# %%
# load image Cacat55.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat55.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat55_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat55_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat55_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat55_90.png')

# %%
# load image Cacat56.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat56.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat56_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat56_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat56_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat56_90.png')

# %%
# load image Cacat57.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat57.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat57_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat57_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat57_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat57_90.png')

# %%
# load image Cacat58.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat58.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat58_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat58_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat58_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat58_90.png')

# %%
# load image Cacat59.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat59.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat59_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat59_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat59_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat59_90.png')

# %%
# load image Cacat60.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat60.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat60_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat60_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat60_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat60_90.png')

# %%
# load image Cacat61.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat61.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat61_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat61_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat61_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat61_90.png')

# %%
# load image Cacat62.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat62.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat62_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat62_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat62_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat62_90.png')

# %%
# load image Cacat63.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat63.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat63_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat63_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat63_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat63_90.png')

# %%
# load image Cacat64.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat64.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat64_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat64_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat64_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat64_90.png')

# %%
# load image Cacat65.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat65.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat65_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat65_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat65_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat65_90.png')

# %%
# load image Cacat66.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat66.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat66_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat66_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat66_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat66_90.png')

# %%
# load image Cacat67.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat67.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat67_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat67_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat67_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat67_90.png')

# %%
# load image Cacat68.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat68.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat68_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat68_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat68_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat68_90.png')

# %%
# load image Cacat69.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat69.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat69_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat69_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat69_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat69_90.png')

# %%
# load image Cacat70.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat70.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat70_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat70_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat70_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat70_90.png')

# %%
# load image Cacat71.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat71.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat71_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat71_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat71_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat71_90.png')

# %%
# load image Cacat72.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat72.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat72_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat72_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat72_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat72_90.png')

# %%
# load image Cacat73.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat73.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat73_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat73_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat73_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat73_90.png')

# %%
# load image Cacat74.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat74.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat74_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat74_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat74_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat74_90.png')

# %%
# load image Cacat75.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat75.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat75_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat75_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat75_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat75_90.png')

# %%
# load image Cacat76.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat76.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat76_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat76_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat76_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat76_90.png')

# %%
# load image Cacat77.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat77.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat77_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat77_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat77_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat77_90.png')

# %%
# load image Cacat78.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat78.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat78_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat78_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat78_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat78_90.png')

# %%
# load image Cacat79.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat79.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat79_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat79_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat79_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat79_90.png')

# %%
# load image Cacat80.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat80.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat80_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat80_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat80_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat80_90.png')

# %%
# load image Cacat81.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat81.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat81_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat81_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat81_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat81_90.png')

# %%
# load image Cacat82.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat82.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat82_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat82_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat82_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat82_90.png')

# %%
# load image Cacat83.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat83.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat83_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat83_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat83_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat83_90.png')

# %%
# load image Cacat84.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat84.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat84_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat84_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat84_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat84_90.png')

# %%
# load image Cacat85.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat85.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat85_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat85_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat85_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat85_90.png')

# %%
# load image Cacat86.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat86.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat86_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat86_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat86_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat86_90.png')

# %%
# load image Cacat87.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat87.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat87_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat87_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat87_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat87_90.png')

# %%
# load image Cacat88.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat88.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat88_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat88_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat88_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat88_90.png')

# %%
# load image Cacat89.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat89.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat89_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat89_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat89_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat89_90.png')

# %%
# load image Cacat90.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat90.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat90_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat90_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat90_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat90_90.png')

# %%
# load image Cacat91.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat91.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat91_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat91_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat91_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat91_90.png')

# %%
# load image Cacat92.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat92.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat92_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat92_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat92_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat92_90.png')

# %%
# load image Cacat93.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat93.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat93_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat93_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat93_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat93_90.png')

# %%
# load image Cacat94.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat94.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat94_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat94_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat94_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat94_90.png')

# %%
# load image Cacat95.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat95.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat95_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat95_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat95_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat95_90.png')

# %%
# load image Cacat96.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat96.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat96_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat96_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat96_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat96_90.png')

# %%
# load image Cacat97.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat97.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat97_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat97_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat97_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat97_90.png')

# %%
# load image Cacat98.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat98.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat98_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat98_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat98_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat98_90.png')

# %%
# load image Cacat99.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat99.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat99_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat99_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat99_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat99_90.png')

# %%
# load image Cacat100.jpg from directory
image = Image.open('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Tidak Cacat/Tidakcacat100.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat100_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat100_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat100_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save('C:/Users/Indriani T Sitorus/Pictures/Dataset remove background_200/Preprocessing/Tidak Cacat/Augmentation/Tidakcacat100_90.png')
